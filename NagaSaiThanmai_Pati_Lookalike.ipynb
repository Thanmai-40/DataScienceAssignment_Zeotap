# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
import csv

# %%
customers = pd.read_csv('Customers.csv')
transactions = pd.read_csv('Transactions.csv')
products = pd.read_csv('Products.csv')

# %%
full_data = transactions.merge(customers, on='CustomerID').merge(products, on='ProductID')

# %%
full_data.drop('Price_x', axis=1, inplace=True)
full_data.rename(columns={'Price_y': 'ProductPrice'}, inplace=True)

# %%
full_data.head()
# Out:
#   TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0        T00001      C0199      P067  2024-08-25 12:38:23         1
# 1        T00112      C0146      P067  2024-05-27 22:23:54         1
# 2        T00166      C0127      P067  2024-04-25 07:38:55         1
# 3        T00272      C0087      P067  2024-03-26 22:55:37         2
# 4        T00363      C0070      P067  2024-03-21 15:10:10         3
#
#    TotalValue     CustomerName         Region  SignupDate  \
# 0      300.68   Andrea Jenkins         Europe  2022-12-03
# 1      300.68  Brittany Harvey           Asia  2024-09-04
# 2      300.68  Kathryn Stevens         Europe  2024-04-04
# 3      601.36  Travis Campbell  South America  2024-04-11
# 4      902.04    Timothy Perez         Europe  2022-03-15
#
#                        ProductName     Category  ProductPrice
# 0  ComfortLiving Bluetooth Speaker  Electronics        300.68
# 1  ComfortLiving Bluetooth Speaker  Electronics        300.68
# 2  ComfortLiving Bluetooth Speaker  Electronics        300.68
# 3  ComfortLiving Bluetooth Speaker  Electronics        300.68
# 4  ComfortLiving Bluetooth Speaker  Electronics        300.68

# %%
customer_features = full_data.groupby('CustomerID').agg(
    TotalSpending=('TotalValue', 'sum'),
    NumTransactions=('TransactionID', 'count'),
    AvgSpending=('TotalValue', 'mean'),
    DistinctCategories=('Category', 'nunique'),
    MostPurchasedCategory=('Category', lambda x: x.mode()[0])
).reset_index()

# %%
customer_features.head()
# Out:
#   CustomerID  TotalSpending  NumTransactions  AvgSpending  DistinctCategories  \
# 0      C0001        3354.52                5      670.904                   3
# 1      C0002        1862.74                4      465.685                   2
# 2      C0003        2725.38                4      681.345                   3
# 3      C0004        5354.88                8      669.360                   3
# 4      C0005        2034.24                3      678.080                   2
#
#   MostPurchasedCategory
# 0           Electronics
# 1              Clothing
# 2            Home Decor
# 3                 Books
# 4           Electronics

# %%
final_data = pd.merge(customer_features, full_data[['CustomerID', 'Region']].drop_duplicates(), on='CustomerID')

# %%
final_data.head()
# Out:
#   CustomerID  TotalSpending  NumTransactions  AvgSpending  DistinctCategories  \
# 0      C0001        3354.52                5      670.904                   3
# 1      C0002        1862.74                4      465.685                   2
# 2      C0003        2725.38                4      681.345                   3
# 3      C0004        5354.88                8      669.360                   3
# 4      C0005        2034.24                3      678.080                   2
#
#   MostPurchasedCategory         Region
# 0           Electronics  South America
# 1              Clothing           Asia
# 2            Home Decor  South America
# 3                 Books  South America
# 4           Electronics           Asia

# %% [markdown]
# Cosine Similarity is used for this because we have both numerical columns and categorical columns (which we will change into numeric using one hot encoding).

# %% [markdown]
# All the numerical columns must be on same scale before performing cosine similarity.

# %% [markdown]
# #### Scaling Numerical Data

# %%
numerical_columns = ['TotalSpending', 'NumTransactions', 'AvgSpending', 'DistinctCategories']
scaler = MinMaxScaler()
final_data[numerical_columns] = scaler.fit_transform(final_data[numerical_columns])

# %%
final_data.head()
# Out:
#   CustomerID  TotalSpending  NumTransactions  AvgSpending  DistinctCategories  \
# 0      C0001       0.308942              0.4     0.474336            0.666667
# 1      C0002       0.168095              0.3     0.308940            0.333333
# 2      C0003       0.249541              0.3     0.482751            0.666667
# 3      C0004       0.497806              0.7     0.473092            0.666667
# 4      C0005       0.184287              0.2     0.480120            0.333333
#
#   MostPurchasedCategory         Region
# 0           Electronics  South America
# 1              Clothing           Asia
# 2            Home Decor  South America
# 3                 Books  South America
# 4           Electronics           Asia

# %% [markdown]
# #### OneHotEncoding for Categorical Data

# %%
encoded_data = pd.get_dummies(final_data, columns=['Region', 'MostPurchasedCategory'], drop_first=True)
encoded_data.head()
# Out:
#   CustomerID  TotalSpending  NumTransactions  AvgSpending  DistinctCategories  \
# 0      C0001       0.308942              0.4     0.474336            0.666667
# 1      C0002       0.168095              0.3     0.308940            0.333333
# 2      C0003       0.249541              0.3     0.482751            0.666667
# 3      C0004       0.497806              0.7     0.473092            0.666667
# 4      C0005       0.184287              0.2     0.480120            0.333333
#
#    Region_Europe  Region_North America  Region_South America  \
# 0          False                 False                  True
# 1          False                 False                 False
# 2          False                 False                  True
# 3          False                 False                  True
# 4          False                 False                 False
#
#    MostPurchasedCategory_Clothing  MostPurchasedCategory_Electronics  \
# 0                           False                               True
# 1                            True                              False
# 2                           False                              False
# 3                           False                              False
# 4                           False                               True
#
#    MostPurchasedCategory_Home Decor
# 0                             False
# 1                             False
# 2                              True
# 3                             False
# 4                             False

# %%
feature_matrix = encoded_data.drop(columns=['CustomerID'])   # Excluding CustomerID for applying similarity matrix
feature_matrix.head()
# Out:
#    TotalSpending  NumTransactions  AvgSpending  DistinctCategories  \
# 0       0.308942              0.4     0.474336            0.666667
# 1       0.168095              0.3     0.308940            0.333333
# 2       0.249541              0.3     0.482751            0.666667
# 3       0.497806              0.7     0.473092            0.666667
# 4       0.184287              0.2     0.480120            0.333333
#
#    Region_Europe  Region_North America  Region_South America  \
# 0          False                 False                  True
# 1          False                 False                 False
# 2          False                 False                  True
# 3          False                 False                  True
# 4          False                 False                 False
#
#    MostPurchasedCategory_Clothing  MostPurchasedCategory_Electronics  \
# 0                           False                               True
# 1                            True                              False
# 2                           False                              False
# 3                           False                              False
# 4                           False                               True
#
#    MostPurchasedCategory_Home Decor
# 0                             False
# 1                             False
# 2                              True
# 3                             False
# 4                             False

# %% [markdown]
# ### Cosine Similarity Matrix

# %%
similarity_matrix = cosine_similarity(feature_matrix)
print(similarity_matrix[:5, :5])
# Out:
# [[1.         0.27467642 0.65018055 0.79260495 0.77987551]
#  [0.27467642 1.         0.25994632 0.3708215  0.25588222]
#  [0.65018055 0.25994632 1.         0.76918279 0.27979194]
#  [0.79260495 0.3708215  0.76918279 1.         0.36905385]
#  [0.77987551 0.25588222 0.27979194 0.36905385 1.        ]]

# %%
top_n = 3
lookalike_dict = {}

# %%
for i, customer_id in enumerate(final_data['CustomerID']):
    scores = similarity_matrix[i]
    scores[i] = -1

    top_indices = np.argsort(scores)[-top_n:][::-1]
 
    similar_customers = [(final_data['CustomerID'].iloc[idx], scores[idx]) for idx in top_indices]

    lookalike_dict[customer_id] = similar_customers

# %%
import pprint

# %%
pprint.pprint(dict(list(lookalike_dict.items())[:5]))
# Out:
# {'C0001': [('C0091', 0.9957792287495667),
#            ('C0192', 0.9937621096989102),
#            ('C0048', 0.986847042579986)],
#  'C0002': [('C0134', 0.9943913144716523),
#            ('C0092', 0.9808070911980618),
#            ('C0106', 0.9685020818148578)],
#  'C0003': [('C0152', 0.9977430428187105),
#            ('C0031', 0.9957034978817269),
#            ('C0158', 0.9929884473690259)],
#  'C0004': [('C0155', 0.9966143151617873),
#            ('C0165', 0.9965374289564791),
#            ('C0126', 0.9901485237060832)],
#  'C0005': [('C0186', 0.9981721462615398),
#            ('C0007', 0.9938444546637496),
#            ('C0140', 0.9840746983621196)]}

# %%
lookalike_list = [{'cust_id': customer_id, 'similar_customers': similar_customers} for customer_id, similar_customers in lookalike_dict.items()]

# %%
lookalike_list[:20]
# Out:
# [{'cust_id': 'C0001',
#   'similar_customers': [('C0091', 0.9957792287495667),
#    ('C0192', 0.9937621096989102),
#    ('C0048', 0.986847042579986)]},
#  {'cust_id': 'C0002',
#   'similar_customers': [('C0134', 0.9943913144716523),
#    ('C0092', 0.9808070911980618),
#    ('C0106', 0.9685020818148578)]},
#  {'cust_id': 'C0003',
#   'similar_customers': [('C0152', 0.9977430428187105),
#    ('C0031', 0.9957034978817269),
#    ('C0158', 0.9929884473690259)]},
#  {'cust_id': 'C0004',
#   'similar_customers': [('C0155', 0.9966143151617873),
#    ('C0165', 0.9965374289564791),
#    ('C0126', 0.9901485237060832)]},
#  {'cust_id': 'C0005',
#   'similar_customers': [('C0186', 0.9981721462615398),
#    ('C0007', 0.9938444546637496),
#    ('C0140', 0.9840746983621196)]},
#  {'cust_id': 'C0006',
#   'similar_customers': [('C0187', 0.9950161911712916),
#    ('C0085', 0.9901594443666802),
#    ('C0011', 0.9849276543239699)]},
#  {'cust_id': 'C0007',
#   'similar_customers': [('C0115', 0.9950528575588955),
#    ('C0140', 0.9942158186456764),
#    ('C0005', 0.9938444546637496)]},
#  {'cust_id': 'C0008',
#   'similar_customers': [('C0059', 0.9713327246571236),
#    ('C0189', 0.9663660672722268),
#    ('C0065', 0.9644610211166939)]},
#  {'cust_id': 'C0009',
#   'similar_customers': [('C0010', 0.9942996907554301),
#    ('C0198', 0.993651343111592),
#    ('C0062', 0.9904350938212682)]},
#  {'cust_id': 'C0010',
#   'similar_customers': [('C0062', 0.9958933980658397),
#    ('C0009', 0.9942996907554301),
#    ('C0198', 0.9899102811391957)]},
#  {'cust_id': 'C0011',
#   'similar_customers': [('C0126', 0.9968487315274338),
#    ('C0187', 0.9951548512983205),
#    ('C0174', 0.9946492164294327)]},
#  {'cust_id': 'C0012',
#   'similar_customers': [('C0195', 0.9967521497047204),
#    ('C0152', 0.9902373649562405),
#    ('C0104', 0.9882816313778778)]},
#  {'cust_id': 'C0013',
#   'similar_customers': [('C0099', 0.9983067923686648),
#    ('C0108', 0.9963702688777722),
#    ('C0107', 0.9875278892143698)]},
#  {'cust_id': 'C0014',
#   'similar_customers': [('C0060', 0.990932990947327),
#    ('C0037', 0.8890423891507444),
#    ('C0089', 0.8864406406769573)]},
#  {'cust_id': 'C0015',
#   'similar_customers': [('C0131', 0.9937228599016138),
#    ('C0125', 0.973784313929326),
#    ('C0036', 0.9668131373038498)]},
#  {'cust_id': 'C0016',
#   'similar_customers': [('C0183', 0.9999971216863889),
#    ('C0030', 0.9905202635707696),
#    ('C0034', 0.9901203478613153)]},
#  {'cust_id': 'C0017',
#   'similar_customers': [('C0075', 0.9973892990707052),
#    ('C0081', 0.9920026907883249),
#    ('C0057', 0.9899822640966759)]},
#  {'cust_id': 'C0018',
#   'similar_customers': [('C0185', 0.9829392417406417),
#    ('C0117', 0.9793448593884597),
#    ('C0046', 0.9752825864343496)]},
#  {'cust_id': 'C0019',
#   'similar_customers': [('C0132', 0.9534210168916026),
#    ('C0070', 0.9484431681557696),
#    ('C0073', 0.9452000358619256)]},
#  {'cust_id': 'C0020',
#   'similar_customers': [('C0050', 0.9643032486535659),
#    ('C0072', 0.9244161535990001),
#    ('C0026', 0.897294320178952)]}]

# %% [markdown]
# ### Saving the First 20 Customer Lookalikes into an csv file

# %%
with open('NagaSaiThanmai_Pati_Lookalike.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['cust_id', 'similar_customers'])
    for row in lookalike_list[:20]:
        writer.writerow([row['cust_id'], row['similar_customers']])
